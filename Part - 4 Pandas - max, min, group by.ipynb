# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Datasets\iris.csv')

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           NaN            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      NaN
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].max()
# Out:
# 7.9

# %%
df['SepalLengthCm'].min()
# Out:
# 3.7

# %%
df.groupby('Species').sum()
# Out:
#                    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa      1275          239.4         160.9           73.2
# Iris-versicolor  3775          296.8         138.5          213.0
# Iris-virginica   6275          329.4         148.7          277.6
#
#                  PetalWidthCm
# Species
# Iris-setosa              12.2
# Iris-versicolor          66.3
# Iris-virginica          101.3

# %%
#select only Iris-setosa records
df[df.Species == 'Iris-setosa']
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           NaN            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            NaN           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            NaN           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           NaN            1.5           0.1  Iris-setosa
# 10  11            3.7           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df[df.Species == 'Iris-setosa'].head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           NaN            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df[df.Species == 'Iris-setosa'].shape
# Out:
# (50, 6)

# %%
df[df.Species == 'Iris-versicolor'].shape
# Out:
# (50, 6)

# %%
df[df.Species == 'Iris-virginica'].shape
# Out:
# (50, 6)

# %%
df.shape
# Out:
# (150, 6)

# %%
df[df.Species == 'Iris-setosa'][['SepalLengthCm','PetalLengthCm']].head(5)
# Out:
#    SepalLengthCm  PetalLengthCm
# 0            5.1            1.4
# 1            4.9            1.4
# 2            4.7            1.3
# 3            NaN            1.5
# 4            5.0            1.4
