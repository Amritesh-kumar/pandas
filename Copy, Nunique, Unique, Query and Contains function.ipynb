# %%
#importing needed library
import pandas as pd

# %%
#loading dataset
data = pd.read_csv('dataset.csv')

# %%
#copying dataset to other object 
#if needed we can compare and check our change
df = data.copy()

# %%
#Displaying dataset few records
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         NaN             360.0
# 1             4583               1508       128.0             360.0
# 2             3000                  0        66.0             360.0
# 3             2583               2358       120.0             360.0
# 4             6000                  0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#get count of unique value
df.Dependents.nunique()
# Out:
# 4

# %%
df.Gender.nunique()
# Out:
# 2

# %%
#get unique values
df.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
#finding  value using query function
df.query("Dependents == '3+'")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 9    LP001100    Male      No         3+      Graduate            No
# 18   LP001206    Male     Yes         3+      Graduate            No
# 25   LP001238    Male     Yes         3+  Not Graduate           Yes
# 30   LP001250    Male     Yes         3+  Not Graduate            No
# 31   LP001253    Male     Yes         3+      Graduate           Yes
# 35   LP001263    Male     Yes         3+      Graduate            No
# 36   LP001264    Male     Yes         3+  Not Graduate           Yes
# 52   LP001384    Male     Yes         3+  Not Graduate            No
# 69   LP001448     NaN     Yes         3+      Graduate            No
# 78   LP001488    Male     Yes         3+      Graduate            No
# 83   LP001536    Male     Yes         3+      Graduate            No
# 99   LP001585     NaN     Yes         3+      Graduate            No
# ...

# %%
df.query("Gender == 'Male'")
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 188  LP002836   Male      No          0      Graduate            No
# 189  LP002837   Male     Yes         3+      Graduate            No
# 190  LP002979   Male     Yes         3+      Graduate            No
# 191  LP002983   Male     Yes          1      Graduate            No
# 192  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                  0         NaN             360.0
# ...

# %%
#using query for multiple condition
df.query("Dependents == '3+' or Dependents == '0'")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 6    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 187  LP002833    Male     Yes          0  Not Graduate            No
# 188  LP002836    Male      No          0      Graduate            No
# 189  LP002837    Male     Yes         3+      Graduate            No
# 190  LP002979    Male     Yes         3+      Graduate            No
# 193  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#using isin function
df[df.Dependents.isin(['0','3+'])]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 6    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 187  LP002833    Male     Yes          0  Not Graduate            No
# 188  LP002836    Male      No          0      Graduate            No
# 189  LP002837    Male     Yes         3+      Graduate            No
# 190  LP002979    Male     Yes         3+      Graduate            No
# 193  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#droping nan value
df.dropna(inplace=True)

# %%
#using contain function to find string
df[df.Gender.str.contains("Fe")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 21   LP001222  Female      No          0      Graduate            No
# 26   LP001241  Female      No          0      Graduate            No
# 37   LP001265  Female      No          0      Graduate            No
# 39   LP001267  Female     Yes          2      Graduate            No
# 47   LP001327  Female     Yes          0      Graduate            No
# 59   LP001404  Female     Yes          0      Graduate            No
# 62   LP001422  Female      No          0      Graduate            No
# 64   LP001430  Female      No          0      Graduate            No
# 65   LP001431  Female      No          0      Graduate            No
# 79   LP001489  Female     Yes          0      Graduate            No
# 94   LP001577  Female     Yes          0      Graduate            No
# 114  LP001692  Female      No          0  Not Graduate            No
# 115  LP001693  Female      No          0      Graduate            No
# ...

# %%
df[df.Dependents.str.contains("1")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 15   LP001198    Male     Yes          1      Graduate            No
# 24   LP001233    Male     Yes          1      Graduate            No
# 34   LP001259    Male     Yes          1      Graduate           Yes
# 58   LP001401    Male     Yes          1      Graduate            No
# 71   LP001451    Male     Yes          1      Graduate           Yes
# 85   LP001543    Male     Yes          1      Graduate            No
# 90   LP001565    Male     Yes          1      Graduate            No
# 106  LP001616    Male     Yes          1      Graduate            No
# 109  LP001674    Male     Yes          1  Not Graduate            No
# 112  LP001688    Male     Yes          1  Not Graduate            No
# 121  LP001713    Male     Yes          1      Graduate           Yes
# 132  LP001870  Female      No          1      Graduate            No
# ...
