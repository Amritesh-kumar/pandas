# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Datasets\iris.csv')

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           NaN            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False          True          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False           True         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    2
# SepalWidthCm     3
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           0.0            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            0.0           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.fillna(method='pad')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           NaN            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.7           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.fillna(df['SepalLengthCm'].mean())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       5.100000      5.848649            1.4           0.2
# 1      2       4.900000      3.000000            1.4           0.2
# 2      3       4.700000      3.200000            1.3           0.2
# 3      4       5.848649      3.100000            1.5           0.2
# 4      5       5.000000      3.600000            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146       6.700000      3.000000            5.2           2.3
# 146  147       6.300000      2.500000            5.0           1.9
# 147  148       6.500000      3.000000            5.2           2.0
# 148  149       6.200000      3.400000            5.4           2.3
# 149  150       5.900000      3.000000            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           NaN            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean(), inplace = True)

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       5.100000           NaN            1.4           0.2  Iris-setosa
# 1   2       4.900000           3.0            1.4           0.2  Iris-setosa
# 2   3       4.700000           3.2            1.3           0.2  Iris-setosa
# 3   4       5.848649           3.1            1.5           0.2  Iris-setosa
# 4   5       5.000000           3.6            1.4           0.2  Iris-setosa

# %%
df['SepalWidthCm'].fillna(df['SepalWidthCm'].mean())
# Out:
# 0      3.048299
# 1      3.000000
# 2      3.200000
# 3      3.100000
# 4      3.600000
#          ...
# 145    3.000000
# 146    2.500000
# 147    3.000000
# 148    3.400000
# 149    3.000000
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       5.100000           NaN            1.4           0.2  Iris-setosa
# 1   2       4.900000           3.0            1.4           0.2  Iris-setosa
# 2   3       4.700000           3.2            1.3           0.2  Iris-setosa
# 3   4       5.848649           3.1            1.5           0.2  Iris-setosa
# 4   5       5.000000           3.6            1.4           0.2  Iris-setosa

# %%
df['SepalWidthCm'].fillna(df['SepalWidthCm'].median(), inplace = True)

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1       5.100000           3.0            1.4           0.2  Iris-setosa
# 1   2       4.900000           3.0            1.4           0.2  Iris-setosa
# 2   3       4.700000           3.2            1.3           0.2  Iris-setosa
# 3   4       5.848649           3.1            1.5           0.2  Iris-setosa
# 4   5       5.000000           3.6            1.4           0.2  Iris-setosa
