# %%
#importing needed library
import pandas as pd

# %%
#loading dataset
df = pd.read_csv('duplicate.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No           0      Graduate            No
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001004   Male     Yes           0      Graduate           Yes
# 3  LP001005   Male     Yes           0  Not Graduate            No
# 4  LP001006   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         NaN             360.0
# 1             4583               1508       128.0             360.0
# 2             3000                  0        66.0             360.0
# 3             2583               2358       120.0             360.0
# 4             6000                  0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df = df.set_index('Loan_ID')

# %%
df.head()
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No           0      Graduate            No
# LP001003   Male     Yes           1      Graduate            No
# LP001004   Male     Yes           0      Graduate           Yes
# LP001005   Male     Yes           0  Not Graduate            No
# LP001006   Male      No           0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001003             4583               1508       128.0             360.0
# LP001004             3000                  0        66.0             360.0
# LP001005             2583               2358       120.0             360.0
# LP001006             6000                  0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# ...

# %%
df.ApplicantIncome.duplicated()
# Out:
# Loan_ID
# LP001002    False
# LP001003    False
# LP001004    False
# LP001005    False
# LP001006    False
# LP001007    False
# LP001008     True
# LP001009    False
# LP001010    False
# LP001011    False
# LP001012    False
# LP001013    False
# LP001014    False
# LP001015    False
# LP001016    False
# LP001017     True
# LP001018     True
# LP001019     True
# Name: ApplicantIncome, dtype: bool

# %%
df.ApplicantIncome.duplicated().sum()
# Out:
# 4

# %%
df[df.ApplicantIncome.duplicated(keep='first')]
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001008   Male     Yes           0  Not Graduate            No
# LP001017   Male      No           0      Graduate            No
# LP001018   Male     Yes           1      Graduate            No
# LP001019   Male     Yes           0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001008             2583               1516        95.0             360.0
# LP001017             5849                  0         NaN             360.0
# LP001018             4583               1508       128.0             360.0
# LP001019             3000                  0        66.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001008             1.0         Urban           Y
# LP001017             1.0         Urban           Y
# LP001018             1.0         Rural           N
# ...

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.ApplicantIncome.duplicated(keep='first')]
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001008   Male     Yes           0  Not Graduate            No
# LP001017   Male      No           0      Graduate            No
# LP001018   Male     Yes           1      Graduate            No
# LP001019   Male     Yes           0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001008             2583               1516        95.0             360.0
# LP001017             5849                  0         NaN             360.0
# LP001018             4583               1508       128.0             360.0
# LP001019             3000                  0        66.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001008             1.0         Urban           Y
# LP001017             1.0         Urban           Y
# LP001018             1.0         Rural           N
# ...

# %%
df[df.ApplicantIncome.duplicated(keep='last')]
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No           0      Graduate            No
# LP001003   Male     Yes           1      Graduate            No
# LP001004   Male     Yes           0      Graduate           Yes
# LP001005   Male     Yes           0  Not Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001003             4583               1508       128.0             360.0
# LP001004             3000                  0        66.0             360.0
# LP001005             2583               2358       120.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001004             1.0         Urban           Y
# ...

# %%
df[df.ApplicantIncome.duplicated(keep=False)]
# Out:
#          Gender Married  Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No           0      Graduate            No
# LP001003   Male     Yes           1      Graduate            No
# LP001004   Male     Yes           0      Graduate           Yes
# LP001005   Male     Yes           0  Not Graduate            No
# LP001008   Male     Yes           0  Not Graduate            No
# LP001017   Male      No           0      Graduate            No
# LP001018   Male     Yes           1      Graduate            No
# LP001019   Male     Yes           0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001003             4583               1508       128.0             360.0
# LP001004             3000                  0        66.0             360.0
# ...
